# %% [markdown]
# # Initial Exploration¶

# %% [raw]
# The main objectives on this project are:
# *Explorating and visualising the data, trying to get some insights about our dataset
# *Getting data in better shape by feature engineering to help us in building better models
# *Building and tuning regression models to get some stable results on predicting time from pick up to arrival

# %%
# Import necessary packages
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt

# %%
# Read train and test data from csv files for visualization
train_data = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/Train.csv')
test_data = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/Test.csv')

# %%
train_data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %%
test_data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
# 3  Order_No_15332  User_Id_2910         Bike              3
# 4  Order_No_21373  User_Id_1205         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
# 3             Business                        17
# 4             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
# 3                             1       1:51:35 PM                           17
# 4                             2      11:30:28 AM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup - Weekday (Mo = 1)  \
# 0                                3  ...                         3
# 1                                5  ...                         5
# 2                                4  ...                         4
# 3                                1  ...                         1
# 4                                2  ...                         2
#
#    Pickup - Time  Distance (KM) Temperature  Precipitation in millimeters  \
# 0     5:06:47 PM              8         NaN                           NaN
# 1     1:25:37 PM              5         NaN                           NaN
# 2    11:57:54 AM              5        22.8                           NaN
# 3     2:16:52 PM              5        24.5                           NaN
# 4    11:56:04 AM              6        24.4                           NaN
#
#    Pickup Lat Pickup Long  Destination Lat  Destination Long      Rider Id
# 0   -1.333275   36.870815        -1.305249         36.822390  Rider_Id_192
# 1   -1.272639   36.794723        -1.277007         36.823907  Rider_Id_868
# 2   -1.290894   36.822971        -1.276574         36.851365   Rider_Id_26
# 3   -1.290503   36.809646        -1.303382         36.790658  Rider_Id_685
# 4   -1.281081   36.814423        -1.266467         36.792161  Rider_Id_858
#
# [5 rows x 25 columns]

# %%
descrip =pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/VariableDefinitions.csv')
descrip.head(35) # 35 to display every description
# Out:
#                                      Order No  \
# 0                                     User Id
# 1                                Vehicle Type
# 2                               Platform Type
# 3                        Personal or Business
# 4                    Placement - Day of Month
# 5                Placement - Weekday (Mo = 1)
# 6                            Placement - Time
# 7                 Confirmation - Day of Month
# 8             Confirmation - Weekday (Mo = 1)
# 9                         Confirmation - Time
# 10           Arrival at Pickup - Day of Month
# 11       Arrival at Pickup - Weekday (Mo = 1)
# 12                   Arrival at Pickup - Time
# 13                      Pickup - Day of Month
# 14                  Pickup - Weekday (Mo = 1)
# 15                              Pickup - Time
# 16      Arrival at Destination - Day of Month
# 17  Arrival at Destination - Weekday (Mo = 1)
# 18              Arrival at Destination - Time
# 19                              Distance (KM)
# 20                                Temperature
# 21               Precipitation in millimeters
# 22                                 Pickup Lat
# 23                                Pickup Long
# 24                            Destination Lat
# 25                           Destination Long
# 26                                   Rider Id
# 27                Time from Pickup to Arrival
# 28                                        NaN
# 29                              Rider Metrics
# 30                                   Rider Id
# 31                               No_Of_Orders
# 32                                        Age
# 33                             Average_Rating
# 34                              No_of_Ratings
#
#                   Unique number identifying the order
# 0   Unique number identifying the customer on a pl...
# 1   For this competition limited to bikes, however...
# 2   Platform used to place the order, there are 4 ...
# 3                                       Customer type
# 4                   Placement - Day of Month i.e 1-31
# 5                    Placement - Weekday (Monday = 1)
# 6   Placement - Time - Time of day the order was p...
# 7                Confirmation - Day of Month i.e 1-31
# 8                 Confirmation - Weekday (Monday = 1)
# 9   Confirmation - Time - Time of day the order wa...
# 10          Arrival at Pickup - Day of Month i.e 1-31
# 11           Arrival at Pickup - Weekday (Monday = 1)
# 12  Time of day the the rider arrived at the locat...
# 13                     Pickup - Day of Month i.e 1-31
# 14                      Pickup - Weekday (Monday = 1)
# 15  Pickup - Time - Time of day the the rider pick...
# 16        Arrival at Delivery - Day of Month i.e 1-31
# 17         Arrival at Delivery - Weekday (Monday = 1)
# 18  Arrival at Delivery Time - Time of day the rid...
# 19            The distance from Pickup to Destination
# 20  Temperature at the time of order placement in ...
# 21   Precipitation at the time of order placement ...
# 22                       Latitude of pick up location
# 23                      Longitude of pick up location
# 24                      Latitude of delivery location
# 25                     Longitude of delivery location
# 26             ID of the Rider who accepted the order
# 27  Time in seconds between 'Pickup' and 'Arrival ...
# 28                                                NaN
# 29                                                NaN
# 30  Unique number identifying the rider (same as i...
# 31           Number of Orders the rider has delivered
# 32  Number of days since the rider delivered the f...
# 33                        Average rating of the rider
# 34   Number of ratings the rider has received. Rat...

# %%
samplesub = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/SampleSubmission.csv')
samplesub.head()
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                        567.0
# 1  Order_No_12736                       4903.0
# 2    Order_No_768                       5649.0
# 3  Order_No_15332                          NaN
# 4  Order_No_21373                          NaN

# %%
rider_data = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/Riders.csv')
rider_data.head()
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156

# %%
train_data.head(5)
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %%
train_data.tail(5)
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 21196             Personal                        20
# 21197             Business                        13
# 21198             Business                         7
# 21199             Personal                         4
# 21200             Business                        26
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 21196                             3       3:54:38 PM
# 21197                             6      10:13:34 AM
# 21198                             4       5:06:16 PM
# 21199                             3       9:31:39 AM
# 21200                             2       2:19:47 PM
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  ...  \
# 21196                           20                                3  ...
# 21197                           13                                6  ...
# 21198                            7                                4  ...
# 21199                            4                                3  ...
# 21200                           26                                2  ...
#
#       Arrival at Destination - Time  Distance (KM)  Temperature  \
# 21196                    4:20:17 PM              3         28.6
# 21197                   10:46:17 AM              7         26.0
# 21198                    6:40:05 PM             20         29.2
# 21199                   10:08:15 AM             13         15.0
# 21200                    3:17:23 PM             12         30.9
#
#       Precipitation in millimeters  Pickup Lat  Pickup Long Destination Lat  \
# 21196                          NaN   -1.258414    36.804800       -1.275285
# 21197                          NaN   -1.307143    36.825009       -1.331619
# 21198                          NaN   -1.286018    36.897534       -1.258414
# 21199                          NaN   -1.250030    36.874167       -1.279209
# 21200                          NaN   -1.255189    36.782203       -1.320157
#
#        Destination Long      Rider Id Time from Pickup to Arrival
# 21196         36.802702  Rider_Id_953                           9
# 21197         36.847976  Rider_Id_155                         770
# 21198         36.804800  Rider_Id_697                        2953
# 21199         36.794872  Rider_Id_347                        1380
# 21200         36.830887  Rider_Id_177                        2128
#
# [5 rows x 29 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Placement - Time                             21201 non-null object
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Arrival at Pickup - Time                     21201 non-null object
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Pickup - Time                                21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  16835 non-null float64
# Precipitation in millimeters                 552 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# dtypes: float64(6), int64(13), object(10)
# memory usage: 4.7+ MB

# %%
train_data.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# min                       1.000000                         1.000000
# 25%                       8.000000                         2.000000
# 50%                      15.000000                         3.000000
# 75%                      23.000000                         5.000000
# max                      31.000000                         7.000000
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# count                      21201.000000                          21201.000000
# mean                          15.653837                              3.240225
# std                            8.798886                              1.567228
# min                            1.000000                              1.000000
# 25%                            8.000000                              2.000000
# 50%                           15.000000                              3.000000
# 75%                           23.000000                              5.000000
# max                           31.000000                              7.000000
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# count           21201.000000               21201.000000
# mean               15.653837                   3.240225
# std                 8.798886                   1.567228
# min                 1.000000                   1.000000
# 25%                 8.000000                   2.000000
# 50%                15.000000                   3.000000
# 75%                23.000000                   5.000000
# max                31.000000                   7.000000
#
#        Arrival at Destination - Day of Month  \
# count                           21201.000000
# mean                               15.653837
# std                                 8.798886
# min                                 1.000000
# 25%                                 8.000000
# 50%                                15.000000
# 75%                                23.000000
# max                                31.000000
#
#        Arrival at Destination - Weekday (Mo = 1)  Distance (KM)   Temperature  \
# count                               21201.000000   21201.000000  16835.000000
# mean                                    3.240225       9.506533     23.258889
# std                                     1.567228       5.668963      3.615768
# min                                     1.000000       1.000000     11.200000
# 25%                                     2.000000       5.000000     20.600000
# 50%                                     3.000000       8.000000     23.500000
# 75%                                     5.000000      13.000000     26.000000
# max                                     7.000000      49.000000     32.100000
#
#        Precipitation in millimeters    Pickup Lat   Pickup Long  \
# count                    552.000000  21201.000000  21201.000000
# mean                       7.905797     -1.281470     36.811264
# std                       17.089971      0.030507      0.037473
# min                        0.100000     -1.438302     36.653621
# 25%                        1.075000     -1.300921     36.784605
# 50%                        2.900000     -1.279395     36.807040
# 75%                        4.900000     -1.257147     36.829741
# max                       99.100000     -1.147170     36.991046
#
#        Destination Lat  Destination Long  Time from Pickup to Arrival
# count     21201.000000      21201.000000                 21201.000000
# mean         -1.282581         36.811220                  1556.920947
# std           0.034824          0.044721                   987.270788
# min          -1.430298         36.606594                     1.000000
# 25%          -1.301201         36.785661                   882.000000
# 50%          -1.284382         36.808002                  1369.000000
# 75%          -1.261177         36.829477                  2040.000000
# max          -1.030225         37.016779                  7883.000000

# %%
train_data.shape
# Out:
# (21201, 29)

# %%
numerical_feature_columns = list(train_data._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['Platform Type',
#  'Placement - Day of Month',
#  'Placement - Weekday (Mo = 1)',
#  'Confirmation - Day of Month',
#  'Confirmation - Weekday (Mo = 1)',
#  'Arrival at Pickup - Day of Month',
#  'Arrival at Pickup - Weekday (Mo = 1)',
#  'Pickup - Day of Month',
#  'Pickup - Weekday (Mo = 1)',
#  'Arrival at Destination - Day of Month',
#  'Arrival at Destination - Weekday (Mo = 1)',
#  'Distance (KM)',
#  'Temperature',
#  'Precipitation in millimeters',
#  'Pickup Lat',
#  'Pickup Long',
#  'Destination Lat',
#  'Destination Long',
#  'Time from Pickup to Arrival']

# %%
categorical_feature_columns = list(set(train_data.columns) - set(train_data._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['Placement - Time',
#  'Personal or Business',
#  'Vehicle Type',
#  'User Id',
#  'Arrival at Destination - Time',
#  'Confirmation - Time',
#  'Pickup - Time',
#  'Rider Id',
#  'Order No',
#  'Arrival at Pickup - Time']

# %% [raw]
# A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# The bin can be of any size

# %%
x = np.random.normal(size=100)
sns.distplot(x, kde=False);

# %% [raw]
# Counting Vehicle type

# %%
sns.countplot('Vehicle Type', data=train_data)

# %% [raw]
# We will plot some important feature against our target.

# %%
sns.lmplot('Distance (KM)', 'Time from Pickup to Arrival', data=train_data, fit_reg=True)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train_data.corr(), cmap='viridis')

# %%
#correlation matrix
k = 33 #number of variables for heatmap
cols = train_data.corr().nlargest(k, 'Time from Pickup to Arrival')['Time from Pickup to Arrival'].index
cm = train_data[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %% [markdown]
# ## Linear Regression

# %%
import sklearn as skl
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#since the model could not convert string to float: '11:49:17 AM' we have to work with simple time
def convert_time(column):
    train_data[column] = pd.to_datetime(train_data[column])
    return (train_data[column] - pd.to_datetime(pd.to_datetime('today').date())).astype('timedelta64[s]')

# %%
train_data['Placement - Time'] = convert_time('Placement - Time')
train_data['Confirmation - Time'] = convert_time('Confirmation - Time')
train_data['Pickup - Time'] = convert_time('Pickup - Time')
train_data['Arrival at Pickup - Time'] = convert_time('Arrival at Pickup - Time')
train_data['Arrival at Destination - Time'] = convert_time('Arrival at Destination - Time')

# %%
train_data['Temperature'] = train_data['Temperature'].fillna((train_data['Temperature'].mean()))

# %%
#Dropping unnecessary variables
train_data.drop(['Order No', 'User Id','Rider Id','Precipitation in millimeters'], axis=1, inplace=True)
train_data.head()
# Out:
#   Vehicle Type  Platform Type Personal or Business  Placement - Day of Month  \
# 0         Bike              3             Business                         9
# 1         Bike              3             Personal                        12
# 2         Bike              3             Business                        30
# 3         Bike              3             Business                        15
# 4         Bike              1             Personal                        13
#
#    Placement - Weekday (Mo = 1)  Placement - Time  \
# 0                             5           34546.0
# 1                             5           40576.0
# 2                             2           45565.0
# 3                             5           33934.0
# 4                             1           35718.0
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           12                                5
# 2                           30                                2
# 3                           15                                5
# 4                           13                                1
#
#    Confirmation - Time  Arrival at Pickup - Day of Month  ...  \
# 0              34810.0                                 9  ...
# 1              41001.0                                12  ...
# 2              45764.0                                30  ...
# 3              33965.0                                15  ...
# 4              35778.0                                13  ...
#
#    Arrival at Destination - Day of Month  \
# 0                                      9
# 1                                     12
# 2                                     30
# 3                                     15
# 4                                     13
#
#    Arrival at Destination - Weekday (Mo = 1)  Arrival at Destination - Time  \
# 0                                          5                        38395.0
# 1                                          5                        44242.0
# 2                                          2                        46838.0
# 3                                          5                        36327.0
# 4                                          1                        37537.0
#
#    Distance (KM)  Temperature  Pickup Lat  Pickup Long  Destination Lat  \
# 0              4    20.400000   -1.317755    36.830370        -1.300406
# 1             16    26.400000   -1.351453    36.899315        -1.295004
# 2              3    23.258889   -1.308284    36.843419        -1.300921
# 3              9    19.200000   -1.281301    36.832396        -1.257147
# 4              9    15.400000   -1.266597    36.792118        -1.295041
#
#    Destination Long  Time from Pickup to Arrival
# 0         36.829741                          745
# 1         36.814358                         1993
# 2         36.828195                          455
# 3         36.795063                         1341
# 4         36.809817                         1214
#
# [5 rows x 25 columns]

# %%
#Inserting numerical variable instead of text for model to pick up numerical values
#transport = {"Vehicle Type":     {"Bike": 1, "Other": 2}}

transport = {"Vehicle Type":     {"Bike": 1, "Other": 2},
                "Personal or Business": {"Personal": 1, "Business": 2,}}

# %%
train_data.replace(transport, inplace=True)
train_data.head()
# Out:
#   Vehicle Type  Platform Type  Personal or Business  Placement - Day of Month  \
# 0            1              3                     2                         9
# 1            1              3                     1                        12
# 2            1              3                     2                        30
# 3            1              3                     2                        15
# 4            1              1                     1                        13
#
#    Placement - Weekday (Mo = 1)  Placement - Time  \
# 0                             5           34546.0
# 1                             5           40576.0
# 2                             2           45565.0
# 3                             5           33934.0
# 4                             1           35718.0
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           12                                5
# 2                           30                                2
# 3                           15                                5
# 4                           13                                1
#
#    Confirmation - Time  Arrival at Pickup - Day of Month  ...  \
# 0              34810.0                                 9  ...
# 1              41001.0                                12  ...
# 2              45764.0                                30  ...
# 3              33965.0                                15  ...
# 4              35778.0                                13  ...
#
#    Arrival at Destination - Day of Month  \
# 0                                      9
# 1                                     12
# 2                                     30
# 3                                     15
# 4                                     13
#
#    Arrival at Destination - Weekday (Mo = 1)  Arrival at Destination - Time  \
# 0                                          5                        38395.0
# 1                                          5                        44242.0
# 2                                          2                        46838.0
# 3                                          5                        36327.0
# 4                                          1                        37537.0
#
#    Distance (KM)  Temperature  Pickup Lat  Pickup Long  Destination Lat  \
# 0              4    20.400000   -1.317755    36.830370        -1.300406
# 1             16    26.400000   -1.351453    36.899315        -1.295004
# 2              3    23.258889   -1.308284    36.843419        -1.300921
# 3              9    19.200000   -1.281301    36.832396        -1.257147
# 4              9    15.400000   -1.266597    36.792118        -1.295041
#
#    Destination Long  Time from Pickup to Arrival
# 0         36.829741                          745
# 1         36.814358                         1993
# 2         36.828195                          455
# 3         36.795063                         1341
# 4         36.809817                         1214
#
# [5 rows x 25 columns]

# %%
X = train_data.drop(['Time from Pickup to Arrival'], axis=1)
Y = train_data['Time from Pickup to Arrival']

#splitting data into training and testing
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.35, random_state=5)
print("**********  features shape  **********\n")
print(X_train.shape)
print(X_test.shape)
print("****************************************")
print("\n**********  labels shape  **********\n")
print(Y_train.shape)
print(Y_test.shape)
print("****************************************")
# Out:
# **********  features shape  **********
#
# (13780, 24)
# (7421, 24)
# ****************************************
#
# **********  labels shape  **********
#
# (13780,)
# (7421,)
# ****************************************

# %%
#Dependent variable continuous
Y_train
# Out:
# 8566     1893
# 15543    4004
# 10646     445
# 4111     1531
# 20923    3861
# 17255     904
# 13105    1020
# 19936     337
# 14982    1956
# 2952     1367
# 10252    1083
# 18354    2458
# 440       651
# 12234    1982
# 4622     1335
# 9936     1903
# 20341     224
# 3505      437
# 10776     941
# 10936    1574
# 20607    2200
# 14607    3726
# 18264    3366
# 2509     1037
# 5992     1144
# 2670     1210
# 8075     2933
# 15695     727
# 18852     456
# 3976     2088
#          ...
# 9166     2814
# 11408    1170
# 4199     1765
# 14546    1889
# 8169     1234
# 16425     659
# 5482      976
# 16009    1058
# 16761    1621
# 2194       10
# 20093    1679
# 2004     1697
# 3503     3441
# 8397     2419
# 9260     1009
# 3185     1257
# 7687     2358
# 20176    1357
# 2718     1282
# 19056     552
# 2459     1082
# 1982      655
# 16103    2241
# 740      2168
# 1032     1016
# 5520     1860
# 3046     4130
# 20463     500
# 18638     677
# 2915     2850
# Name: Time from Pickup to Arrival, Length: 13780, dtype: int64

# %%
####First Feature column
# create a Python list of feature names
#feature_cols = ['Distance (KM)', 'Temperature']

# use the list to select a subset of the original DataFrame
#X = train_data[feature_cols]

###########

##Second feature column after realising that we didnt test for 
#the first time that how related they would be on y ('Time from Pickup to Arrival')

# create a Python list of feature names
feature_cols = ['Distance (KM)', 'Temperature', 'Confirmation - Day of Month']

# use the list to select a subset of the original DataFrame
X = train_data[feature_cols]

# select a Series from the DataFrame
y = train_data['Time from Pickup to Arrival']

# %%
sns.pairplot( X);

# %% [raw]
# Distance is not normally distributed and the deliveries range can raech 40 KM while temparature is normally distributed ,also note that temparature range from around 15 to 33.
# Temperature and Distance (KM) have the impact on our y estimate

# %%
#Trying to get insight that after doing my 1st feature columns

# %%
#low multicollinearity between the features
X_train.corr()
# Out:
#                                            Platform Type  \
# Platform Type                                   1.000000
# Personal or Business                            0.714149
# Placement - Day of Month                        0.008269
# Placement - Weekday (Mo = 1)                   -0.046397
# Placement - Time                               -0.027013
# Confirmation - Day of Month                     0.008279
# Confirmation - Weekday (Mo = 1)                -0.046345
# Confirmation - Time                            -0.023829
# Arrival at Pickup - Day of Month                0.008279
# Arrival at Pickup - Weekday (Mo = 1)           -0.046345
# Arrival at Pickup - Time                       -0.028651
# Pickup - Day of Month                           0.008279
# Pickup - Weekday (Mo = 1)                      -0.046345
# Pickup - Time                                  -0.024096
# Arrival at Destination - Day of Month           0.008279
# Arrival at Destination - Weekday (Mo = 1)      -0.046345
# Arrival at Destination - Time                  -0.024096
# Distance (KM)                                   0.009995
# Temperature                                     0.219916
# Pickup Lat                                     -0.001783
# Pickup Long                                     0.016281
# Destination Lat                                 0.011808
# Destination Long                                0.054657
#
#                                            Personal or Business  \
# Platform Type                                          0.714149
# Personal or Business                                   1.000000
# Placement - Day of Month                               0.001452
# Placement - Weekday (Mo = 1)                          -0.042669
# Placement - Time                                      -0.033873
# Confirmation - Day of Month                            0.001463
# Confirmation - Weekday (Mo = 1)                       -0.042608
# Confirmation - Time                                   -0.029421
# Arrival at Pickup - Day of Month                       0.001463
# Arrival at Pickup - Weekday (Mo = 1)                  -0.042608
# Arrival at Pickup - Time                              -0.035619
# Pickup - Day of Month                                  0.001463
# Pickup - Weekday (Mo = 1)                             -0.042608
# Pickup - Time                                         -0.029437
# Arrival at Destination - Day of Month                  0.001463
# Arrival at Destination - Weekday (Mo = 1)             -0.042608
# Arrival at Destination - Time                         -0.029967
# Distance (KM)                                          0.011579
# Temperature                                            0.207483
# Pickup Lat                                             0.022654
# Pickup Long                                            0.030524
# Destination Lat                                        0.008450
# Destination Long                                       0.066389
#
#                                            Placement - Day of Month  \
# Platform Type                                              0.008269
# Personal or Business                                       0.001452
# Placement - Day of Month                                   1.000000
# Placement - Weekday (Mo = 1)                               0.028154
# Placement - Time                                           0.007981
# Confirmation - Day of Month                                0.999998
# Confirmation - Weekday (Mo = 1)                            0.028112
# Confirmation - Time                                        0.008344
# Arrival at Pickup - Day of Month                           0.999998
# Arrival at Pickup - Weekday (Mo = 1)                       0.028112
# Arrival at Pickup - Time                                   0.006931
# Pickup - Day of Month                                      0.999998
# Pickup - Weekday (Mo = 1)                                  0.028112
# Pickup - Time                                              0.006872
# Arrival at Destination - Day of Month                      0.999998
# Arrival at Destination - Weekday (Mo = 1)                  0.028112
# Arrival at Destination - Time                              0.004404
# Distance (KM)                                             -0.012488
# Temperature                                                0.011862
# Pickup Lat                                                -0.008856
# Pickup Long                                               -0.007307
# Destination Lat                                            0.003986
# Destination Long                                          -0.002785
#
#                                            Placement - Weekday (Mo = 1)  \
# Platform Type                                                 -0.046397
# Personal or Business                                          -0.042669
# Placement - Day of Month                                       0.028154
# Placement - Weekday (Mo = 1)                                   1.000000
# Placement - Time                                              -0.005311
# Confirmation - Day of Month                                    0.028129
# Confirmation - Weekday (Mo = 1)                                0.999926
# Confirmation - Time                                           -0.004401
# Arrival at Pickup - Day of Month                               0.028129
# Arrival at Pickup - Weekday (Mo = 1)                           0.999926
# Arrival at Pickup - Time                                      -0.002167
# Pickup - Day of Month                                          0.028129
# Pickup - Weekday (Mo = 1)                                      0.999926
# Pickup - Time                                                 -0.001088
# Arrival at Destination - Day of Month                          0.028129
# Arrival at Destination - Weekday (Mo = 1)                      0.999926
# Arrival at Destination - Time                                  0.000128
# Distance (KM)                                                 -0.001978
# Temperature                                                    0.031250
# Pickup Lat                                                     0.006446
# Pickup Long                                                    0.005948
# Destination Lat                                               -0.009629
# Destination Long                                              -0.003348
#
#                                            Placement - Time  \
# Platform Type                                     -0.027013
# Personal or Business                              -0.033873
# Placement - Day of Month                           0.007981
# Placement - Weekday (Mo = 1)                      -0.005311
# Placement - Time                                   1.000000
# Confirmation - Day of Month                        0.007984
# Confirmation - Weekday (Mo = 1)                   -0.005297
# Confirmation - Time                                0.993450
# Arrival at Pickup - Day of Month                   0.007984
# Arrival at Pickup - Weekday (Mo = 1)              -0.005297
# Arrival at Pickup - Time                           0.990078
# Pickup - Day of Month                              0.007984
# Pickup - Weekday (Mo = 1)                         -0.005297
# Pickup - Time                                      0.987005
# Arrival at Destination - Day of Month              0.007984
# Arrival at Destination - Weekday (Mo = 1)         -0.005297
# Arrival at Destination - Time                      0.980212
# Distance (KM)                                     -0.041032
# Temperature                                        0.359548
# Pickup Lat                                         0.061890
# Pickup Long                                       -0.039170
# Destination Lat                                    0.013671
# Destination Long                                  -0.009879
#
#                                            Confirmation - Day of Month  \
# Platform Type                                                 0.008279
# Personal or Business                                          0.001463
# Placement - Day of Month                                      0.999998
# Placement - Weekday (Mo = 1)                                  0.028129
# Placement - Time                                              0.007984
# Confirmation - Day of Month                                   1.000000
# Confirmation - Weekday (Mo = 1)                               0.028114
# Confirmation - Time                                           0.008348
# Arrival at Pickup - Day of Month                              1.000000
# Arrival at Pickup - Weekday (Mo = 1)                          0.028114
# Arrival at Pickup - Time                                      0.006937
# Pickup - Day of Month                                         1.000000
# Pickup - Weekday (Mo = 1)                                     0.028114
# Pickup - Time                                                 0.006877
# Arrival at Destination - Day of Month                         1.000000
# Arrival at Destination - Weekday (Mo = 1)                     0.028114
# Arrival at Destination - Time                                 0.004411
# Distance (KM)                                                -0.012490
# Temperature                                                   0.011865
# Pickup Lat                                                   -0.008846
# Pickup Long                                                  -0.007300
# Destination Lat                                               0.003999
# Destination Long                                             -0.002792
#
#                                            Confirmation - Weekday (Mo = 1)  \
# Platform Type                                                    -0.046345
# Personal or Business                                             -0.042608
# Placement - Day of Month                                          0.028112
# Placement - Weekday (Mo = 1)                                      0.999926
# Placement - Time                                                 -0.005297
# Confirmation - Day of Month                                       0.028114
# Confirmation - Weekday (Mo = 1)                                   1.000000
# Confirmation - Time                                              -0.004376
# Arrival at Pickup - Day of Month                                  0.028114
# Arrival at Pickup - Weekday (Mo = 1)                              1.000000
# Arrival at Pickup - Time                                         -0.002138
# Pickup - Day of Month                                             0.028114
# Pickup - Weekday (Mo = 1)                                         1.000000
# Pickup - Time                                                    -0.001057
# Arrival at Destination - Day of Month                             0.028114
# Arrival at Destination - Weekday (Mo = 1)                         1.000000
# Arrival at Destination - Time                                     0.000167
# Distance (KM)                                                    -0.001991
# Temperature                                                       0.031264
# Pickup Lat                                                        0.006501
# Pickup Long                                                       0.005991
# Destination Lat                                                  -0.009555
# Destination Long                                                 -0.003386
#
#                                            Confirmation - Time  \
# Platform Type                                        -0.023829
# Personal or Business                                 -0.029421
# Placement - Day of Month                              0.008344
# Placement - Weekday (Mo = 1)                         -0.004401
# Placement - Time                                      0.993450
# Confirmation - Day of Month                           0.008348
# Confirmation - Weekday (Mo = 1)                      -0.004376
# Confirmation - Time                                   1.000000
# Arrival at Pickup - Day of Month                      0.008348
# Arrival at Pickup - Weekday (Mo = 1)                 -0.004376
# Arrival at Pickup - Time                              0.997143
# Pickup - Day of Month                                 0.008348
# Pickup - Weekday (Mo = 1)                            -0.004376
# Pickup - Time                                         0.994175
# Arrival at Destination - Day of Month                 0.008348
# Arrival at Destination - Weekday (Mo = 1)            -0.004376
# Arrival at Destination - Time                         0.987736
# Distance (KM)                                        -0.044259
# Temperature                                           0.357785
# Pickup Lat                                            0.057663
# Pickup Long                                          -0.033413
# Destination Lat                                       0.012533
# Destination Long                                     -0.007248
#
#                                            Arrival at Pickup - Day of Month  \
# Platform Type                                                      0.008279
# Personal or Business                                               0.001463
# Placement - Day of Month                                           0.999998
# Placement - Weekday (Mo = 1)                                       0.028129
# Placement - Time                                                   0.007984
# Confirmation - Day of Month                                        1.000000
# Confirmation - Weekday (Mo = 1)                                    0.028114
# Confirmation - Time                                                0.008348
# Arrival at Pickup - Day of Month                                   1.000000
# Arrival at Pickup - Weekday (Mo = 1)                               0.028114
# Arrival at Pickup - Time                                           0.006937
# Pickup - Day of Month                                              1.000000
# Pickup - Weekday (Mo = 1)                                          0.028114
# Pickup - Time                                                      0.006877
# Arrival at Destination - Day of Month                              1.000000
# Arrival at Destination - Weekday (Mo = 1)                          0.028114
# Arrival at Destination - Time                                      0.004411
# Distance (KM)                                                     -0.012490
# Temperature                                                        0.011865
# Pickup Lat                                                        -0.008846
# Pickup Long                                                       -0.007300
# Destination Lat                                                    0.003999
# Destination Long                                                  -0.002792
#
#                                            Arrival at Pickup - Weekday (Mo = 1)  \
# Platform Type                                                         -0.046345
# Personal or Business                                                  -0.042608
# Placement - Day of Month                                               0.028112
# Placement - Weekday (Mo = 1)                                           0.999926
# Placement - Time                                                      -0.005297
# Confirmation - Day of Month                                            0.028114
# Confirmation - Weekday (Mo = 1)                                        1.000000
# Confirmation - Time                                                   -0.004376
# Arrival at Pickup - Day of Month                                       0.028114
# Arrival at Pickup - Weekday (Mo = 1)                                   1.000000
# Arrival at Pickup - Time                                              -0.002138
# Pickup - Day of Month                                                  0.028114
# Pickup - Weekday (Mo = 1)                                              1.000000
# Pickup - Time                                                         -0.001057
# Arrival at Destination - Day of Month                                  0.028114
# Arrival at Destination - Weekday (Mo = 1)                              1.000000
# Arrival at Destination - Time                                          0.000167
# Distance (KM)                                                         -0.001991
# Temperature                                                            0.031264
# Pickup Lat                                                             0.006501
# Pickup Long                                                            0.005991
# Destination Lat                                                       -0.009555
# Destination Long                                                      -0.003386
#
#                                            ...  Pickup - Time  \
# Platform Type                              ...      -0.024096
# Personal or Business                       ...      -0.029437
# Placement - Day of Month                   ...       0.006872
# Placement - Weekday (Mo = 1)               ...      -0.001088
# Placement - Time                           ...       0.987005
# Confirmation - Day of Month                ...       0.006877
# Confirmation - Weekday (Mo = 1)            ...      -0.001057
# Confirmation - Time                        ...       0.994175
# Arrival at Pickup - Day of Month           ...       0.006877
# Arrival at Pickup - Weekday (Mo = 1)       ...      -0.001057
# Arrival at Pickup - Time                   ...       0.996479
# Pickup - Day of Month                      ...       0.006877
# Pickup - Weekday (Mo = 1)                  ...      -0.001057
# Pickup - Time                              ...       1.000000
# Arrival at Destination - Day of Month      ...       0.006877
# Arrival at Destination - Weekday (Mo = 1)  ...      -0.001057
# Arrival at Destination - Time              ...       0.994225
# Distance (KM)                              ...      -0.028202
# Temperature                                ...       0.359998
# Pickup Lat                                 ...       0.043411
# Pickup Long                                ...      -0.012485
# Destination Lat                            ...       0.010486
# Destination Long                           ...      -0.007928
#
#                                            Arrival at Destination - Day of Month  \
# Platform Type                                                           0.008279
# Personal or Business                                                    0.001463
# Placement - Day of Month                                                0.999998
# Placement - Weekday (Mo = 1)                                            0.028129
# Placement - Time                                                        0.007984
# Confirmation - Day of Month                                             1.000000
# Confirmation - Weekday (Mo = 1)                                         0.028114
# Confirmation - Time                                                     0.008348
# Arrival at Pickup - Day of Month                                        1.000000
# Arrival at Pickup - Weekday (Mo = 1)                                    0.028114
# Arrival at Pickup - Time                                                0.006937
# Pickup - Day of Month                                                   1.000000
# Pickup - Weekday (Mo = 1)                                               0.028114
# Pickup - Time                                                           0.006877
# Arrival at Destination - Day of Month                                   1.000000
# Arrival at Destination - Weekday (Mo = 1)                               0.028114
# Arrival at Destination - Time                                           0.004411
# Distance (KM)                                                          -0.012490
# Temperature                                                             0.011865
# Pickup Lat                                                             -0.008846
# Pickup Long                                                            -0.007300
# Destination Lat                                                         0.003999
# Destination Long                                                       -0.002792
#
#                                            Arrival at Destination - Weekday (Mo = 1)  \
# Platform Type                                                              -0.046345
# Personal or Business                                                       -0.042608
# Placement - Day of Month                                                    0.028112
# Placement - Weekday (Mo = 1)                                                0.999926
# Placement - Time                                                           -0.005297
# Confirmation - Day of Month                                                 0.028114
# Confirmation - Weekday (Mo = 1)                                             1.000000
# Confirmation - Time                                                        -0.004376
# Arrival at Pickup - Day of Month                                            0.028114
# Arrival at Pickup - Weekday (Mo = 1)                                        1.000000
# Arrival at Pickup - Time                                                   -0.002138
# Pickup - Day of Month                                                       0.028114
# Pickup - Weekday (Mo = 1)                                                   1.000000
# Pickup - Time                                                              -0.001057
# Arrival at Destination - Day of Month                                       0.028114
# Arrival at Destination - Weekday (Mo = 1)                                   1.000000
# Arrival at Destination - Time                                               0.000167
# Distance (KM)                                                              -0.001991
# Temperature                                                                 0.031264
# Pickup Lat                                                                  0.006501
# Pickup Long                                                                 0.005991
# Destination Lat                                                            -0.009555
# Destination Long                                                           -0.003386
#
#                                            Arrival at Destination - Time  \
# Platform Type                                                  -0.024096
# Personal or Business                                           -0.029967
# Placement - Day of Month                                        0.004404
# Placement - Weekday (Mo = 1)                                    0.000128
# Placement - Time                                                0.980212
# Confirmation - Day of Month                                     0.004411
# Confirmation - Weekday (Mo = 1)                                 0.000167
# Confirmation - Time                                             0.987736
# Arrival at Pickup - Day of Month                                0.004411
# Arrival at Pickup - Weekday (Mo = 1)                            0.000167
# Arrival at Pickup - Time                                        0.991436
# Pickup - Day of Month                                           0.004411
# Pickup - Weekday (Mo = 1)                                       0.000167
# Pickup - Time                                                   0.994225
# Arrival at Destination - Day of Month                           0.004411
# Arrival at Destination - Weekday (Mo = 1)                       0.000167
# Arrival at Destination - Time                                   1.000000
# Distance (KM)                                                   0.034255
# Temperature                                                     0.358553
# Pickup Lat                                                      0.037263
# Pickup Long                                                    -0.007084
# Destination Lat                                                 0.004238
# Destination Long                                               -0.000538
#
#                                            Distance (KM)  Temperature  \
# Platform Type                                   0.009995     0.219916
# Personal or Business                            0.011579     0.207483
# Placement - Day of Month                       -0.012488     0.011862
# Placement - Weekday (Mo = 1)                   -0.001978     0.031250
# Placement - Time                               -0.041032     0.359548
# Confirmation - Day of Month                    -0.012490     0.011865
# Confirmation - Weekday (Mo = 1)                -0.001991     0.031264
# Confirmation - Time                            -0.044259     0.357785
# Arrival at Pickup - Day of Month               -0.012490     0.011865
# Arrival at Pickup - Weekday (Mo = 1)           -0.001991     0.031264
# Arrival at Pickup - Time                       -0.036603     0.356065
# Pickup - Day of Month                          -0.012490     0.011865
# Pickup - Weekday (Mo = 1)                      -0.001991     0.031264
# Pickup - Time                                  -0.028202     0.359998
# Arrival at Destination - Day of Month          -0.012490     0.011865
# Arrival at Destination - Weekday (Mo = 1)      -0.001991     0.031264
# Arrival at Destination - Time                   0.034255     0.358553
# Distance (KM)                                   1.000000     0.001807
# Temperature                                     0.001807     1.000000
# Pickup Lat                                     -0.128256     0.021272
# Pickup Long                                     0.172258     0.006059
# Destination Lat                                -0.077113     0.013355
# Destination Long                                0.131097     0.021941
#
#                                            Pickup Lat  Pickup Long  \
# Platform Type                               -0.001783     0.016281
# Personal or Business                         0.022654     0.030524
# Placement - Day of Month                    -0.008856    -0.007307
# Placement - Weekday (Mo = 1)                 0.006446     0.005948
# Placement - Time                             0.061890    -0.039170
# Confirmation - Day of Month                 -0.008846    -0.007300
# Confirmation - Weekday (Mo = 1)              0.006501     0.005991
# Confirmation - Time                          0.057663    -0.033413
# Arrival at Pickup - Day of Month            -0.008846    -0.007300
# Arrival at Pickup - Weekday (Mo = 1)         0.006501     0.005991
# Arrival at Pickup - Time                     0.054330    -0.027267
# Pickup - Day of Month                       -0.008846    -0.007300
# Pickup - Weekday (Mo = 1)                    0.006501     0.005991
# Pickup - Time                                0.043411    -0.012485
# Arrival at Destination - Day of Month       -0.008846    -0.007300
# Arrival at Destination - Weekday (Mo = 1)    0.006501     0.005991
# Arrival at Destination - Time                0.037263    -0.007084
# Distance (KM)                               -0.128256     0.172258
# Temperature                                  0.021272     0.006059
# Pickup Lat                                   1.000000    -0.154741
# Pickup Long                                 -0.154741     1.000000
# Destination Lat                              0.115025     0.015142
# Destination Long                             0.047446     0.079419
#
#                                            Destination Lat  Destination Long
# Platform Type                                     0.011808          0.054657
# Personal or Business                              0.008450          0.066389
# Placement - Day of Month                          0.003986         -0.002785
# Placement - Weekday (Mo = 1)                     -0.009629         -0.003348
# Placement - Time                                  0.013671         -0.009879
# Confirmation - Day of Month                       0.003999         -0.002792
# Confirmation - Weekday (Mo = 1)                  -0.009555         -0.003386
# Confirmation - Time                               0.012533         -0.007248
# Arrival at Pickup - Day of Month                  0.003999         -0.002792
# Arrival at Pickup - Weekday (Mo = 1)             -0.009555         -0.003386
# Arrival at Pickup - Time                          0.012952         -0.006057
# Pickup - Day of Month                             0.003999         -0.002792
# Pickup - Weekday (Mo = 1)                        -0.009555         -0.003386
# Pickup - Time                                     0.010486         -0.007928
# Arrival at Destination - Day of Month             0.003999         -0.002792
# Arrival at Destination - Weekday (Mo = 1)        -0.009555         -0.003386
# Arrival at Destination - Time                     0.004238         -0.000538
# Distance (KM)                                    -0.077113          0.131097
# Temperature                                       0.013355          0.021941
# Pickup Lat                                        0.115025          0.047446
# Pickup Long                                       0.015142          0.079419
# Destination Lat                                   1.000000          0.054882
# Destination Long                                  0.054882          1.000000
#
# [23 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.heatmap(X_train.corr(), annot = True)

# %%
#Shows that distance play a major role in for time from pickup to arrival
sns.lmplot(x='Time from Pickup to Arrival', y='Distance (KM)', data=train_data, ci=95, height=6, aspect=2);

# %%
#Creating a Linear regression object
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#fitting the model
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Checking the intercept
print(model.intercept_)

#Checking the coefficients of the independent variables
coeff_df = pd.DataFrame(model.coef_, X_train.columns, columns=['Coefficients'])
coeff_df
# Out:
# -4.0245140553452075e-11
#                                            Coefficients
# Vehicle Type                               0.000000e+00
# Platform Type                             -3.240319e-13
# Personal or Business                       2.227428e-13
# Placement - Day of Month                   6.554511e-13
# Placement - Weekday (Mo = 1)               5.888806e-13
# Placement - Time                           1.300921e-15
# Confirmation - Day of Month               -8.964376e-14
# Confirmation - Weekday (Mo = 1)           -1.560453e-13
# Confirmation - Time                       -1.205024e-15
# Arrival at Pickup - Day of Month          -8.975478e-14
# Arrival at Pickup - Weekday (Mo = 1)      -1.560453e-13
# Arrival at Pickup - Time                  -1.163943e-15
# Pickup - Day of Month                     -8.975478e-14
# Pickup - Weekday (Mo = 1)                 -1.560453e-13
# Pickup - Time                             -1.000000e+00
# Arrival at Destination - Day of Month     -8.975478e-14
# Arrival at Destination - Weekday (Mo = 1) -1.560505e-13
# Arrival at Destination - Time              1.000000e+00
# Distance (KM)                              5.607706e-15
# Temperature                                7.950386e-15
# Pickup Lat                                -1.501104e-12
# Pickup Long                                1.418240e-14
# Destination Lat                            8.687375e-13
# Destination Long                           6.680834e-13

# %%
#getting the estimate of y
y_estimate = model.predict(X_test)

# %%
residuals = Y_test - y_estimate

# %% [raw]
# After realising that actually the data coefficients(mentioned above) are more of the categorical variable ,then opt out to research about models that can handle categorical data

# %% [markdown]
# ### Also looked at Random forest(with RMSE =753 using train_data ONLY)

# %%
#regressor = RandomForestRegressor(n_estimators=228,
#                                  max_depth=100,
#                                  max_features=4, min_samples_leaf=10,
#                                  min_samples_split=8,
#                                  random_state=0)
#regressor.fit(X_train, y_train)
#y_pred = regressor.predict(X_test)

# %%
#mean_squared_error(y_test/60, y_pred/60)  #157.60978552509135

# %%
#rms = sqrt(mean_squared_error(y_test, y_pred))
#print(rms)
#753.2564157644651

# %% [raw]
# Reason which made me to let this one go its because it was leaving some required estimate unpredicted

# %% [markdown]
#  ### Regression Model (CatBoostRegressor)

# %% [raw]
# Purpose of CatBoost
# Training and applying models for the regression problems. When using the applying methods only the predicted class is returned. Provides compatibility with the scikit-learn tools.

# %% [raw]
# **Parameter and Description	Default value
# metadata	The key-value string pairs to store in the model's metadata storage after the training.	None
#
#
# cat_features
# A one-dimensional array of categorical columns indices (specified as integers) or names (specified as strings).
#
# This array can contain both indices and names for different elements.
#
# If any features in the cat_features parameter are specified as names instead of indices, feature names must be provided for the training dataset. Therefore, the type of the X parameter in the future calls of the fit function must be either catboost.Pool with defined feature names data or pandas.DataFrame with defined column names.
#
# Note.
# If this parameter is not None and the training dataset passed as the value of the X parameter to the fit function of this class has the catboost.Pool type, CatBoost checks the equivalence of the categorical features indices specification in this object and the one in the catboost.Pool object.
#
# If this parameter is not None, passing objects of the catboost.FeaturesData type as the X parameter to the fit function of this class is prohibited.
# None (all features are either considered numerical or of other types if specified precisely)

# %% [raw]
# For Info : https://catboost.ai/docs/concepts/python-reference_catboostregressor.html

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
import catboost
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import math
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
descrip =pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/VariableDefinitions.csv')
train_data = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/Train.csv')
samplesub = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/SampleSubmission.csv')
riders = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/Riders.csv')
test_data = pd.read_csv('C:/Users/smesh/Desktop/Explore Data Science/Sendy/Test.csv')

# %%
train_data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %%
test_data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
# 3  Order_No_15332  User_Id_2910         Bike              3
# 4  Order_No_21373  User_Id_1205         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
# 3             Business                        17
# 4             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
# 3                             1       1:51:35 PM                           17
# 4                             2      11:30:28 AM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup - Weekday (Mo = 1)  \
# 0                                3  ...                         3
# 1                                5  ...                         5
# 2                                4  ...                         4
# 3                                1  ...                         1
# 4                                2  ...                         2
#
#    Pickup - Time  Distance (KM) Temperature  Precipitation in millimeters  \
# 0     5:06:47 PM              8         NaN                           NaN
# 1     1:25:37 PM              5         NaN                           NaN
# 2    11:57:54 AM              5        22.8                           NaN
# 3     2:16:52 PM              5        24.5                           NaN
# 4    11:56:04 AM              6        24.4                           NaN
#
#    Pickup Lat Pickup Long  Destination Lat  Destination Long      Rider Id
# 0   -1.333275   36.870815        -1.305249         36.822390  Rider_Id_192
# 1   -1.272639   36.794723        -1.277007         36.823907  Rider_Id_868
# 2   -1.290894   36.822971        -1.276574         36.851365   Rider_Id_26
# 3   -1.290503   36.809646        -1.303382         36.790658  Rider_Id_685
# 4   -1.281081   36.814423        -1.266467         36.792161  Rider_Id_858
#
# [5 rows x 25 columns]

# %%
train = train_data.shape[0]
test = test_data.shape[0]

combined_data = pd.concat((train_data, test_data)).reset_index(drop=True)
print("combined_data size is : {}".format(combined_data.shape))
# Out:
# combined_data size is : (28269, 29)
# C:\Users\smesh\Documents\Anaconda\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
# Checking merged shape
display(combined_data.shape)
# Out:
# (28269, 29)

# %%
# Checking features and target columns
display(combined_data.columns)
# Out:
# Index(['Arrival at Destination - Day of Month',
#        'Arrival at Destination - Time',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Pickup - Day of Month', 'Arrival at Pickup - Time',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Confirmation - Day of Month',
#        'Confirmation - Time', 'Confirmation - Weekday (Mo = 1)',
#        'Destination Lat', 'Destination Long', 'Distance (KM)', 'Order No',
#        'Personal or Business', 'Pickup - Day of Month', 'Pickup - Time',
#        'Pickup - Weekday (Mo = 1)', 'Pickup Lat', 'Pickup Long',
#        'Placement - Day of Month', 'Placement - Time',
#        'Placement - Weekday (Mo = 1)', 'Platform Type',
#        'Precipitation in millimeters', 'Rider Id', 'Temperature',
#        'Time from Pickup to Arrival', 'User Id', 'Vehicle Type'],
#       dtype='object')

# %%
# Checking dtypes
display(combined_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28269 entries, 0 to 28268
# Data columns (total 29 columns):
# Arrival at Destination - Day of Month        21201 non-null float64
# Arrival at Destination - Time                21201 non-null object
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null float64
# Arrival at Pickup - Day of Month             28269 non-null int64
# Arrival at Pickup - Time                     28269 non-null object
# Arrival at Pickup - Weekday (Mo = 1)         28269 non-null int64
# Confirmation - Day of Month                  28269 non-null int64
# Confirmation - Time                          28269 non-null object
# Confirmation - Weekday (Mo = 1)              28269 non-null int64
# Destination Lat                              28269 non-null float64
# Destination Long                             28269 non-null float64
# Distance (KM)                                28269 non-null int64
# Order No                                     28269 non-null object
# Personal or Business                         28269 non-null object
# Pickup - Day of Month                        28269 non-null int64
# Pickup - Time                                28269 non-null object
# Pickup - Weekday (Mo = 1)                    28269 non-null int64
# Pickup Lat                                   28269 non-null float64
# Pickup Long                                  28269 non-null float64
# Placement - Day of Month                     28269 non-null int64
# Placement - Time                             28269 non-null object
# Placement - Weekday (Mo = 1)                 28269 non-null int64
# Platform Type                                28269 non-null int64
# Precipitation in millimeters                 751 non-null float64
# Rider Id                                     28269 non-null object
# Temperature                                  22466 non-null float64
# Time from Pickup to Arrival                  21201 non-null float64
# User Id                                      28269 non-null object
# Vehicle Type                                 28269 non-null object
# dtypes: float64(9), int64(10), object(10)
# memory usage: 6.3+ MB
# None

# %%
#low multicollinearity between the features
combined_data.corr()
# Out:
#                                            Arrival at Destination - Day of Month  \
# Arrival at Destination - Day of Month                                   1.000000
# Arrival at Destination - Weekday (Mo = 1)                               0.026123
# Arrival at Pickup - Day of Month                                        1.000000
# Arrival at Pickup - Weekday (Mo = 1)                                    0.026123
# Confirmation - Day of Month                                             1.000000
# Confirmation - Weekday (Mo = 1)                                         0.026123
# Destination Lat                                                         0.007550
# Destination Long                                                        0.002073
# Distance (KM)                                                          -0.007587
# Pickup - Day of Month                                                   1.000000
# Pickup - Weekday (Mo = 1)                                               0.026123
# Pickup Lat                                                             -0.004923
# Pickup Long                                                            -0.005448
# Placement - Day of Month                                                0.999998
# Placement - Weekday (Mo = 1)                                            0.026132
# Platform Type                                                           0.012770
# Precipitation in millimeters                                           -0.204143
# Temperature                                                             0.013099
# Time from Pickup to Arrival                                            -0.014701
#
#                                            Arrival at Destination - Weekday (Mo = 1)  \
# Arrival at Destination - Day of Month                                       0.026123
# Arrival at Destination - Weekday (Mo = 1)                                   1.000000
# Arrival at Pickup - Day of Month                                            0.026123
# Arrival at Pickup - Weekday (Mo = 1)                                        1.000000
# Confirmation - Day of Month                                                 0.026123
# Confirmation - Weekday (Mo = 1)                                             1.000000
# Destination Lat                                                            -0.004251
# Destination Long                                                           -0.000900
# Distance (KM)                                                               0.003574
# Pickup - Day of Month                                                       0.026123
# Pickup - Weekday (Mo = 1)                                                   1.000000
# Pickup Lat                                                                 -0.000883
# Pickup Long                                                                 0.011036
# Placement - Day of Month                                                    0.026122
# Placement - Weekday (Mo = 1)                                                0.999952
# Platform Type                                                              -0.058005
# Precipitation in millimeters                                               -0.050592
# Temperature                                                                 0.031074
# Time from Pickup to Arrival                                                 0.009744
#
#                                            Arrival at Pickup - Day of Month  \
# Arrival at Destination - Day of Month                              1.000000
# Arrival at Destination - Weekday (Mo = 1)                          0.026123
# Arrival at Pickup - Day of Month                                   1.000000
# Arrival at Pickup - Weekday (Mo = 1)                               0.023891
# Confirmation - Day of Month                                        1.000000
# Confirmation - Weekday (Mo = 1)                                    0.023891
# Destination Lat                                                    0.003888
# Destination Long                                                   0.003049
# Distance (KM)                                                     -0.001979
# Pickup - Day of Month                                              1.000000
# Pickup - Weekday (Mo = 1)                                          0.023891
# Pickup Lat                                                        -0.005087
# Pickup Long                                                        0.000764
# Placement - Day of Month                                           0.999999
# Placement - Weekday (Mo = 1)                                       0.023898
# Platform Type                                                      0.013963
# Precipitation in millimeters                                      -0.223946
# Temperature                                                        0.008007
# Time from Pickup to Arrival                                       -0.014701
#
#                                            Arrival at Pickup - Weekday (Mo = 1)  \
# Arrival at Destination - Day of Month                                  0.026123
# Arrival at Destination - Weekday (Mo = 1)                              1.000000
# Arrival at Pickup - Day of Month                                       0.023891
# Arrival at Pickup - Weekday (Mo = 1)                                   1.000000
# Confirmation - Day of Month                                            0.023891
# Confirmation - Weekday (Mo = 1)                                        1.000000
# Destination Lat                                                        0.002706
# Destination Long                                                      -0.000934
# Distance (KM)                                                          0.009388
# Pickup - Day of Month                                                  0.023891
# Pickup - Weekday (Mo = 1)                                              1.000000
# Pickup Lat                                                             0.000241
# Pickup Long                                                            0.010503
# Placement - Day of Month                                               0.023890
# Placement - Weekday (Mo = 1)                                           0.999964
# Platform Type                                                         -0.058612
# Precipitation in millimeters                                          -0.031377
# Temperature                                                            0.030179
# Time from Pickup to Arrival                                            0.009744
#
#                                            Confirmation - Day of Month  \
# Arrival at Destination - Day of Month                         1.000000
# Arrival at Destination - Weekday (Mo = 1)                     0.026123
# Arrival at Pickup - Day of Month                              1.000000
# Arrival at Pickup - Weekday (Mo = 1)                          0.023891
# Confirmation - Day of Month                                   1.000000
# Confirmation - Weekday (Mo = 1)                               0.023891
# Destination Lat                                               0.003888
# Destination Long                                              0.003049
# Distance (KM)                                                -0.001979
# Pickup - Day of Month                                         1.000000
# Pickup - Weekday (Mo = 1)                                     0.023891
# Pickup Lat                                                   -0.005087
# Pickup Long                                                   0.000764
# Placement - Day of Month                                      0.999999
# Placement - Weekday (Mo = 1)                                  0.023898
# Platform Type                                                 0.013963
# Precipitation in millimeters                                 -0.223946
# Temperature                                                   0.008007
# Time from Pickup to Arrival                                  -0.014701
#
#                                            Confirmation - Weekday (Mo = 1)  \
# Arrival at Destination - Day of Month                             0.026123
# Arrival at Destination - Weekday (Mo = 1)                         1.000000
# Arrival at Pickup - Day of Month                                  0.023891
# Arrival at Pickup - Weekday (Mo = 1)                              1.000000
# Confirmation - Day of Month                                       0.023891
# Confirmation - Weekday (Mo = 1)                                   1.000000
# Destination Lat                                                   0.002706
# Destination Long                                                 -0.000934
# Distance (KM)                                                     0.009388
# Pickup - Day of Month                                             0.023891
# Pickup - Weekday (Mo = 1)                                         1.000000
# Pickup Lat                                                        0.000241
# Pickup Long                                                       0.010503
# Placement - Day of Month                                          0.023890
# Placement - Weekday (Mo = 1)                                      0.999964
# Platform Type                                                    -0.058612
# Precipitation in millimeters                                     -0.031377
# Temperature                                                       0.030179
# Time from Pickup to Arrival                                       0.009744
#
#                                            Destination Lat  Destination Long  \
# Arrival at Destination - Day of Month             0.007550          0.002073
# Arrival at Destination - Weekday (Mo = 1)        -0.004251         -0.000900
# Arrival at Pickup - Day of Month                  0.003888          0.003049
# Arrival at Pickup - Weekday (Mo = 1)              0.002706         -0.000934
# Confirmation - Day of Month                       0.003888          0.003049
# Confirmation - Weekday (Mo = 1)                   0.002706         -0.000934
# Destination Lat                                   1.000000          0.044218
# Destination Long                                  0.044218          1.000000
# Distance (KM)                                    -0.076642          0.145198
# Pickup - Day of Month                             0.003888          0.003049
# Pickup - Weekday (Mo = 1)                         0.002706         -0.000934
# Pickup Lat                                        0.109250          0.051481
# Pickup Long                                       0.016541          0.081843
# Placement - Day of Month                          0.003882          0.003052
# Placement - Weekday (Mo = 1)                      0.002670         -0.000915
# Platform Type                                     0.006558          0.042425
# Precipitation in millimeters                      0.008294          0.034903
# Temperature                                       0.011653          0.019175
# Time from Pickup to Arrival                      -0.061872          0.070425
#
#                                            Distance (KM)  \
# Arrival at Destination - Day of Month          -0.007587
# Arrival at Destination - Weekday (Mo = 1)       0.003574
# Arrival at Pickup - Day of Month               -0.001979
# Arrival at Pickup - Weekday (Mo = 1)            0.009388
# Confirmation - Day of Month                    -0.001979
# Confirmation - Weekday (Mo = 1)                 0.009388
# Destination Lat                                -0.076642
# Destination Long                                0.145198
# Distance (KM)                                   1.000000
# Pickup - Day of Month                          -0.001979
# Pickup - Weekday (Mo = 1)                       0.009388
# Pickup Lat                                     -0.128315
# Pickup Long                                     0.180356
# Placement - Day of Month                       -0.001978
# Placement - Weekday (Mo = 1)                    0.009394
# Platform Type                                   0.005981
# Precipitation in millimeters                   -0.039817
# Temperature                                    -0.004892
# Time from Pickup to Arrival                     0.580608
#
#                                            Pickup - Day of Month  \
# Arrival at Destination - Day of Month                   1.000000
# Arrival at Destination - Weekday (Mo = 1)               0.026123
# Arrival at Pickup - Day of Month                        1.000000
# Arrival at Pickup - Weekday (Mo = 1)                    0.023891
# Confirmation - Day of Month                             1.000000
# Confirmation - Weekday (Mo = 1)                         0.023891
# Destination Lat                                         0.003888
# Destination Long                                        0.003049
# Distance (KM)                                          -0.001979
# Pickup - Day of Month                                   1.000000
# Pickup - Weekday (Mo = 1)                               0.023891
# Pickup Lat                                             -0.005087
# Pickup Long                                             0.000764
# Placement - Day of Month                                0.999999
# Placement - Weekday (Mo = 1)                            0.023898
# Platform Type                                           0.013963
# Precipitation in millimeters                           -0.223946
# Temperature                                             0.008007
# Time from Pickup to Arrival                            -0.014701
#
#                                            Pickup - Weekday (Mo = 1)  \
# Arrival at Destination - Day of Month                       0.026123
# Arrival at Destination - Weekday (Mo = 1)                   1.000000
# Arrival at Pickup - Day of Month                            0.023891
# Arrival at Pickup - Weekday (Mo = 1)                        1.000000
# Confirmation - Day of Month                                 0.023891
# Confirmation - Weekday (Mo = 1)                             1.000000
# Destination Lat                                             0.002706
# Destination Long                                           -0.000934
# Distance (KM)                                               0.009388
# Pickup - Day of Month                                       0.023891
# Pickup - Weekday (Mo = 1)                                   1.000000
# Pickup Lat                                                  0.000241
# Pickup Long                                                 0.010503
# Placement - Day of Month                                    0.023890
# Placement - Weekday (Mo = 1)                                0.999964
# Platform Type                                              -0.058612
# Precipitation in millimeters                               -0.031377
# Temperature                                                 0.030179
# Time from Pickup to Arrival                                 0.009744
#
#                                            Pickup Lat  Pickup Long  \
# Arrival at Destination - Day of Month       -0.004923    -0.005448
# Arrival at Destination - Weekday (Mo = 1)   -0.000883     0.011036
# Arrival at Pickup - Day of Month            -0.005087     0.000764
# Arrival at Pickup - Weekday (Mo = 1)         0.000241     0.010503
# Confirmation - Day of Month                 -0.005087     0.000764
# Confirmation - Weekday (Mo = 1)              0.000241     0.010503
# Destination Lat                              0.109250     0.016541
# Destination Long                             0.051481     0.081843
# Distance (KM)                               -0.128315     0.180356
# Pickup - Day of Month                       -0.005087     0.000764
# Pickup - Weekday (Mo = 1)                    0.000241     0.010503
# Pickup Lat                                   1.000000    -0.152014
# Pickup Long                                 -0.152014     1.000000
# Placement - Day of Month                    -0.005092     0.000761
# Placement - Weekday (Mo = 1)                 0.000214     0.010483
# Platform Type                               -0.003386     0.019767
# Precipitation in millimeters                -0.025638    -0.037794
# Temperature                                  0.020400     0.013193
# Time from Pickup to Arrival                 -0.053823     0.060285
#
#                                            Placement - Day of Month  \
# Arrival at Destination - Day of Month                      0.999998
# Arrival at Destination - Weekday (Mo = 1)                  0.026122
# Arrival at Pickup - Day of Month                           0.999999
# Arrival at Pickup - Weekday (Mo = 1)                       0.023890
# Confirmation - Day of Month                                0.999999
# Confirmation - Weekday (Mo = 1)                            0.023890
# Destination Lat                                            0.003882
# Destination Long                                           0.003052
# Distance (KM)                                             -0.001978
# Pickup - Day of Month                                      0.999999
# Pickup - Weekday (Mo = 1)                                  0.023890
# Pickup Lat                                                -0.005092
# Pickup Long                                                0.000761
# Placement - Day of Month                                   1.000000
# Placement - Weekday (Mo = 1)                               0.023910
# Platform Type                                              0.013958
# Precipitation in millimeters                              -0.223946
# Temperature                                                0.008006
# Time from Pickup to Arrival                               -0.014710
#
#                                            Placement - Weekday (Mo = 1)  \
# Arrival at Destination - Day of Month                          0.026132
# Arrival at Destination - Weekday (Mo = 1)                      0.999952
# Arrival at Pickup - Day of Month                               0.023898
# Arrival at Pickup - Weekday (Mo = 1)                           0.999964
# Confirmation - Day of Month                                    0.023898
# Confirmation - Weekday (Mo = 1)                                0.999964
# Destination Lat                                                0.002670
# Destination Long                                              -0.000915
# Distance (KM)                                                  0.009394
# Pickup - Day of Month                                          0.023898
# Pickup - Weekday (Mo = 1)                                      0.999964
# Pickup Lat                                                     0.000214
# Pickup Long                                                    0.010483
# Placement - Day of Month                                       0.023910
# Placement - Weekday (Mo = 1)                                   1.000000
# Platform Type                                                 -0.058637
# Precipitation in millimeters                                  -0.031377
# Temperature                                                    0.030172
# Time from Pickup to Arrival                                    0.009693
#
#                                            Platform Type  \
# Arrival at Destination - Day of Month           0.012770
# Arrival at Destination - Weekday (Mo = 1)      -0.058005
# Arrival at Pickup - Day of Month                0.013963
# Arrival at Pickup - Weekday (Mo = 1)           -0.058612
# Confirmation - Day of Month                     0.013963
# Confirmation - Weekday (Mo = 1)                -0.058612
# Destination Lat                                 0.006558
# Destination Long                                0.042425
# Distance (KM)                                   0.005981
# Pickup - Day of Month                           0.013963
# Pickup - Weekday (Mo = 1)                      -0.058612
# Pickup Lat                                     -0.003386
# Pickup Long                                     0.019767
# Placement - Day of Month                        0.013958
# Placement - Weekday (Mo = 1)                   -0.058637
# Platform Type                                   1.000000
# Precipitation in millimeters                   -0.050634
# Temperature                                     0.220127
# Time from Pickup to Arrival                    -0.003827
#
#                                            Precipitation in millimeters  \
# Arrival at Destination - Day of Month                         -0.204143
# Arrival at Destination - Weekday (Mo = 1)                     -0.050592
# Arrival at Pickup - Day of Month                              -0.223946
# Arrival at Pickup - Weekday (Mo = 1)                          -0.031377
# Confirmation - Day of Month                                   -0.223946
# Confirmation - Weekday (Mo = 1)                               -0.031377
# Destination Lat                                                0.008294
# Destination Long                                               0.034903
# Distance (KM)                                                 -0.039817
# Pickup - Day of Month                                         -0.223946
# Pickup - Weekday (Mo = 1)                                     -0.031377
# Pickup Lat                                                    -0.025638
# Pickup Long                                                   -0.037794
# Placement - Day of Month                                      -0.223946
# Placement - Weekday (Mo = 1)                                  -0.031377
# Platform Type                                                 -0.050634
# Precipitation in millimeters                                   1.000000
# Temperature                                                   -0.169106
# Time from Pickup to Arrival                                    0.024756
#
#                                            Temperature  \
# Arrival at Destination - Day of Month         0.013099
# Arrival at Destination - Weekday (Mo = 1)     0.031074
# Arrival at Pickup - Day of Month              0.008007
# Arrival at Pickup - Weekday (Mo = 1)          0.030179
# Confirmation - Day of Month                   0.008007
# Confirmation - Weekday (Mo = 1)               0.030179
# Destination Lat                               0.011653
# Destination Long                              0.019175
# Distance (KM)                                -0.004892
# Pickup - Day of Month                         0.008007
# Pickup - Weekday (Mo = 1)                     0.030179
# Pickup Lat                                    0.020400
# Pickup Long                                   0.013193
# Placement - Day of Month                      0.008006
# Placement - Weekday (Mo = 1)                  0.030172
# Platform Type                                 0.220127
# Precipitation in millimeters                 -0.169106
# Temperature                                   1.000000
# Time from Pickup to Arrival                   0.006465
#
#                                            Time from Pickup to Arrival
# Arrival at Destination - Day of Month                        -0.014701
# Arrival at Destination - Weekday (Mo = 1)                     0.009744
# Arrival at Pickup - Day of Month                             -0.014701
# Arrival at Pickup - Weekday (Mo = 1)                          0.009744
# Confirmation - Day of Month                                  -0.014701
# Confirmation - Weekday (Mo = 1)                               0.009744
# Destination Lat                                              -0.061872
# Destination Long                                              0.070425
# Distance (KM)                                                 0.580608
# Pickup - Day of Month                                        -0.014701
# Pickup - Weekday (Mo = 1)                                     0.009744
# Pickup Lat                                                   -0.053823
# Pickup Long                                                   0.060285
# Placement - Day of Month                                     -0.014710
# Placement - Weekday (Mo = 1)                                  0.009693
# Platform Type                                                -0.003827
# Precipitation in millimeters                                  0.024756
# Temperature                                                   0.006465
# Time from Pickup to Arrival                                   1.000000

# %%
#Finding numerical columns
numerical_feature_columns = list(combined_data._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['Arrival at Destination - Day of Month',
#  'Arrival at Destination - Weekday (Mo = 1)',
#  'Arrival at Pickup - Day of Month',
#  'Arrival at Pickup - Weekday (Mo = 1)',
#  'Confirmation - Day of Month',
#  'Confirmation - Weekday (Mo = 1)',
#  'Destination Lat',
#  'Destination Long',
#  'Distance (KM)',
#  'Pickup - Day of Month',
#  'Pickup - Weekday (Mo = 1)',
#  'Pickup Lat',
#  'Pickup Long',
#  'Placement - Day of Month',
#  'Placement - Weekday (Mo = 1)',
#  'Platform Type',
#  'Precipitation in millimeters',
#  'Temperature',
#  'Time from Pickup to Arrival']

# %%
#Looking Categorical columns 
categorical_feature_columns = list(set(train_data.columns) - set(train_data._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['Placement - Time',
#  'Personal or Business',
#  'Vehicle Type',
#  'User Id',
#  'Arrival at Destination - Time',
#  'Confirmation - Time',
#  'Pickup - Time',
#  'Rider Id',
#  'Order No',
#  'Arrival at Pickup - Time']

# %%
combined_data['Placement_Datetime'] = pd.to_datetime(combined_data['Placement - Time'])
combined_data.loc[:, 'Placement_Date'] = combined_data['Placement_Datetime'].dt.date
combined_data['Confirmation_datetime'] = pd.to_datetime(combined_data['Confirmation - Time'])
combined_data['Trip_Duration'] = (combined_data['Confirmation_datetime'] -combined_data['Placement_Datetime']).map(lambda x: x.total_seconds())

combined_data.drop(["Confirmation_datetime","Placement_Date","Placement_Datetime"],axis =1,inplace = True)

# %%
combined_data.drop(["Arrival at Destination - Day of Month","Arrival at Destination - Weekday (Mo = 1)","Arrival at Destination - Time"],
              axis = 1,inplace =True)

# %%
combined_data.head()
# Out:
#    Arrival at Pickup - Day of Month Arrival at Pickup - Time  \
# 0                                 9              10:04:47 AM
# 1                                12              11:40:22 AM
# 2                                30              12:49:34 PM
# 3                                15               9:37:56 AM
# 4                                13              10:03:53 AM
#
#    Arrival at Pickup - Weekday (Mo = 1)  Confirmation - Day of Month  \
# 0                                     5                            9
# 1                                     5                           12
# 2                                     2                           30
# 3                                     5                           15
# 4                                     1                           13
#
#   Confirmation - Time  Confirmation - Weekday (Mo = 1)  Destination Lat  \
# 0          9:40:10 AM                                5        -1.300406
# 1         11:23:21 AM                                5        -1.295004
# 2         12:42:44 PM                                2        -1.300921
# 3          9:26:05 AM                                5        -1.257147
# 4          9:56:18 AM                                1        -1.295041
#
#    Destination Long  Distance (KM)        Order No  ... Placement - Time  \
# 0         36.829741              4   Order_No_4211  ...       9:35:46 AM
# 1         36.814358             16  Order_No_25375  ...      11:16:16 AM
# 2         36.828195              3   Order_No_1899  ...      12:39:25 PM
# 3         36.795063              9   Order_No_9336  ...       9:25:34 AM
# 4         36.809817              9  Order_No_27883  ...       9:55:18 AM
#
#    Placement - Weekday (Mo = 1) Platform Type  Precipitation in millimeters  \
# 0                             5             3                           NaN
# 1                             5             3                           NaN
# 2                             2             3                           NaN
# 3                             5             3                           NaN
# 4                             1             1                           NaN
#
#        Rider Id  Temperature  Time from Pickup to Arrival       User Id  \
# 0  Rider_Id_432         20.4                        745.0   User_Id_633
# 1  Rider_Id_856         26.4                       1993.0  User_Id_2285
# 2  Rider_Id_155          NaN                        455.0   User_Id_265
# 3  Rider_Id_855         19.2                       1341.0  User_Id_1402
# 4  Rider_Id_770         15.4                       1214.0  User_Id_1737
#
#    Vehicle Type  Trip_Duration
# 0          Bike          264.0
# 1          Bike          425.0
# 2          Bike          199.0
# 3          Bike           31.0
# 4          Bike           60.0
#
# [5 rows x 27 columns]

# %%
combined_data.drop('Trip_Duration',axis = 1,inplace = True)

# %%
combined_data = pd.merge(combined_data,riders,how = 'left',on = ['Rider Id'])

# %%
combined_data.isnull().sum()
# Out:
# Arrival at Pickup - Day of Month            0
# Arrival at Pickup - Time                    0
# Arrival at Pickup - Weekday (Mo = 1)        0
# Confirmation - Day of Month                 0
# Confirmation - Time                         0
# Confirmation - Weekday (Mo = 1)             0
# Destination Lat                             0
# Destination Long                            0
# Distance (KM)                               0
# Order No                                    0
# Personal or Business                        0
# Pickup - Day of Month                       0
# Pickup - Time                               0
# Pickup - Weekday (Mo = 1)                   0
# Pickup Lat                                  0
# Pickup Long                                 0
# Placement - Day of Month                    0
# Placement - Time                            0
# Placement - Weekday (Mo = 1)                0
# Platform Type                               0
# Precipitation in millimeters            27518
# Rider Id                                    0
# Temperature                              5803
# Time from Pickup to Arrival              7068
# User Id                                     0
# Vehicle Type                                0
# No_Of_Orders                                0
# Age                                         0
# Average_Rating                              0
# No_of_Ratings                               0
# dtype: int64

# %%
combined_data['Temperature'] = combined_data['Temperature'].fillna((combined_data['Temperature'].mean()))

# %%
combined_data['Precipitation in millimeters'] = combined_data['Precipitation in millimeters'].fillna(0)

# %%
combined_data.isnull().sum()
# Out:
# Arrival at Pickup - Day of Month           0
# Arrival at Pickup - Time                   0
# Arrival at Pickup - Weekday (Mo = 1)       0
# Confirmation - Day of Month                0
# Confirmation - Time                        0
# Confirmation - Weekday (Mo = 1)            0
# Destination Lat                            0
# Destination Long                           0
# Distance (KM)                              0
# Order No                                   0
# Personal or Business                       0
# Pickup - Day of Month                      0
# Pickup - Time                              0
# Pickup - Weekday (Mo = 1)                  0
# Pickup Lat                                 0
# Pickup Long                                0
# Placement - Day of Month                   0
# Placement - Time                           0
# Placement - Weekday (Mo = 1)               0
# Platform Type                              0
# Precipitation in millimeters               0
# Rider Id                                   0
# Temperature                                0
# Time from Pickup to Arrival             7068
# User Id                                    0
# Vehicle Type                               0
# No_Of_Orders                               0
# Age                                        0
# Average_Rating                             0
# No_of_Ratings                              0
# dtype: int64

# %%
combined_data['Arrival at Pickup - Time'] = pd.to_datetime(combined_data['Arrival at Pickup - Time'])
combined_data['A_hour'] = combined_data['Arrival at Pickup - Time'].dt.hour
combined_data['A_seconds'] = combined_data['Arrival at Pickup - Time'].dt.second
combined_data['A_minutes'] = combined_data['Arrival at Pickup - Time'].dt.minute
combined_data['am_or_pm_confirm'] = combined_data['Confirmation - Time'].astype('str').apply(lambda x:x.split(' ')[-1])

# %%
combined_data['Confirmation - Time'] = pd.to_datetime(combined_data['Confirmation - Time'])

# %%
combined_data['C_hour'] = combined_data['Confirmation - Time'].dt.hour
combined_data['C_min'] = combined_data['Confirmation - Time'].dt.minute
combined_data['C_sec'] = combined_data['Confirmation - Time'].dt.second

# %%
combined_data.head()
# Out:
#    Arrival at Pickup - Day of Month Arrival at Pickup - Time  \
# 0                                 9      2020-05-23 10:04:47
# 1                                12      2020-05-23 11:40:22
# 2                                30      2020-05-23 12:49:34
# 3                                15      2020-05-23 09:37:56
# 4                                13      2020-05-23 10:03:53
#
#    Arrival at Pickup - Weekday (Mo = 1)  Confirmation - Day of Month  \
# 0                                     5                            9
# 1                                     5                           12
# 2                                     2                           30
# 3                                     5                           15
# 4                                     1                           13
#
#   Confirmation - Time  Confirmation - Weekday (Mo = 1)  Destination Lat  \
# 0 2020-05-23 09:40:10                                5        -1.300406
# 1 2020-05-23 11:23:21                                5        -1.295004
# 2 2020-05-23 12:42:44                                2        -1.300921
# 3 2020-05-23 09:26:05                                5        -1.257147
# 4 2020-05-23 09:56:18                                1        -1.295041
#
#    Destination Long  Distance (KM)        Order No  ...   Age  Average_Rating  \
# 0         36.829741              4   Order_No_4211  ...  1309            13.8
# 1         36.814358             16  Order_No_25375  ...   339            13.6
# 2         36.828195              3   Order_No_1899  ...   242            12.5
# 3         36.795063              9   Order_No_9336  ...   283            14.5
# 4         36.809817              9  Order_No_27883  ...   872            14.1
#
#   No_of_Ratings  A_hour  A_seconds  A_minutes  am_or_pm_confirm C_hour  C_min  \
# 0           549      10         47          4                AM      9     40
# 1            69      11         22         40                AM     11     23
# 2           114      12         34         49                PM     12     42
# 3           113       9         56         37                AM      9     26
# 4           533      10         53          3                AM      9     56
#
#    C_sec
# 0     10
# 1     21
# 2     44
# 3      5
# 4     18
#
# [5 rows x 37 columns]

# %%
combined_data.drop(['Arrival at Pickup - Time','Confirmation - Time'],axis = 1,inplace = True)

# %%
combined_data.drop('Order No',axis =1,inplace = True)

# %%
combined_data.isnull().sum()
# Out:
# Arrival at Pickup - Day of Month           0
# Arrival at Pickup - Weekday (Mo = 1)       0
# Confirmation - Day of Month                0
# Confirmation - Weekday (Mo = 1)            0
# Destination Lat                            0
# Destination Long                           0
# Distance (KM)                              0
# Personal or Business                       0
# Pickup - Day of Month                      0
# Pickup - Time                              0
# Pickup - Weekday (Mo = 1)                  0
# Pickup Lat                                 0
# Pickup Long                                0
# Placement - Day of Month                   0
# Placement - Time                           0
# Placement - Weekday (Mo = 1)               0
# Platform Type                              0
# Precipitation in millimeters               0
# Rider Id                                   0
# Temperature                                0
# Time from Pickup to Arrival             7068
# User Id                                    0
# Vehicle Type                               0
# No_Of_Orders                               0
# Age                                        0
# Average_Rating                             0
# No_of_Ratings                              0
# A_hour                                     0
# A_seconds                                  0
# A_minutes                                  0
# am_or_pm_confirm                           0
# C_hour                                     0
# C_min                                      0
# C_sec                                      0
# dtype: int64

# %%
combined_data.drop(['Pickup - Time','Placement - Time','Rider Id'],axis =1,inplace = True)

# %%
transport = {"Vehicle Type":     {"Bike": 1, "Other": 2},
                "Personal or Business": {"Personal": 1, "Business": 2,}}

# %%
combined_data.replace(transport, inplace=True)

# %%
combined_data = pd.get_dummies(combined_data)

# %%
#Get the new dataset
train_data = combined_data[:train]
test_data = combined_data[train:]

# %%
test_data.drop("Time from Pickup to Arrival",axis = 1,inplace = True)
# Out:
# C:\Users\smesh\Documents\Anaconda\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## Model

# %%
#Creating a training set for modeling and validation set to check model performance
X = train_data.drop(columns='Time from Pickup to Arrival')
Y = train_data['Time from Pickup to Arrival']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
#Look at the data type of variables
X.dtypes
# Out:
# Arrival at Pickup - Day of Month          int64
# Arrival at Pickup - Weekday (Mo = 1)      int64
# Confirmation - Day of Month               int64
# Confirmation - Weekday (Mo = 1)           int64
# Destination Lat                         float64
# Destination Long                        float64
# Distance (KM)                             int64
# Personal or Business                      int64
# Pickup - Day of Month                     int64
# Pickup - Weekday (Mo = 1)                 int64
# Pickup Lat                              float64
# Pickup Long                             float64
# Placement - Day of Month                  int64
# Placement - Weekday (Mo = 1)              int64
# Platform Type                             int64
# Precipitation in millimeters            float64
# Temperature                             float64
# No_Of_Orders                              int64
# Age                                       int64
# Average_Rating                          float64
# No_of_Ratings                             int64
# A_hour                                    int64
# A_seconds                                 int64
# A_minutes                                 int64
# C_hour                                    int64
# C_min                                     int64
# C_sec                                     int64
# User Id_User_Id_0                         uint8
# User Id_User_Id_1                         uint8
# User Id_User_Id_10                        uint8
#                                          ...
# User Id_User_Id_975                       uint8
# User Id_User_Id_976                       uint8
# User Id_User_Id_977                       uint8
# User Id_User_Id_978                       uint8
# User Id_User_Id_979                       uint8
# User Id_User_Id_98                        uint8
# User Id_User_Id_980                       uint8
# User Id_User_Id_981                       uint8
# User Id_User_Id_982                       uint8
# User Id_User_Id_983                       uint8
# User Id_User_Id_984                       uint8
# User Id_User_Id_985                       uint8
# User Id_User_Id_986                       uint8
# User Id_User_Id_987                       uint8
# User Id_User_Id_988                       uint8
# User Id_User_Id_989                       uint8
# User Id_User_Id_99                        uint8
# User Id_User_Id_990                       uint8
# User Id_User_Id_991                       uint8
# User Id_User_Id_992                       uint8
# User Id_User_Id_993                       uint8
# User Id_User_Id_994                       uint8
# User Id_User_Id_995                       uint8
# User Id_User_Id_996                       uint8
# User Id_User_Id_997                       uint8
# User Id_User_Id_998                       uint8
# User Id_User_Id_999                       uint8
# Vehicle Type_1                            uint8
# am_or_pm_confirm_AM                       uint8
# am_or_pm_confirm_PM                       uint8
# Length: 3812, dtype: object

# %% [raw]
# We will only identify categorical variables. We will not perform any preprocessing steps for categorical variables:

# %%
categorical_features_indices = np.where(X.dtypes != np.float)[0]

# %%
#categorical_features_indices.head()

# %%
regressor = CatBoostRegressor(iterations=600,
                              learning_rate=0.1,
                              depth=4,
                              l2_leaf_reg=10,
                              bootstrap_type='Bernoulli',
                              subsample=0.7,
                              leaf_estimation_iterations=10,
                              metric_period=20,
                              od_type='Iter',
                              od_wait=45,
                              random_seed=42,
                              loss_function='RMSE',
                              allow_writing_files=False)
#regressor.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X, Y),plot=True)

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round( regressor.feature_importances_,2)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances.head(15)
# Out:
#                   importance
# feature
# Distance (KM)          41.73
# Average_Rating          6.75
# Destination Lat         6.74
# No_Of_Orders            6.26
# Pickup Lat              5.55
# Age                     5.27
# No_of_Ratings           3.43
# Destination Long        3.30
# Pickup Long             2.39
# A_minutes               1.45
# C_min                   1.12
# A_seconds               0.86
# Temperature             0.72
# A_hour                  0.71
# C_sec                   0.70

# %%
regressor.fit(train_data.drop(['Time from Pickup to Arrival'], axis =1), train_data['Time from Pickup to Arrival'])
# Out:
# 0:	learn: 957.5695379	total: 309ms	remaining: 3m 4s
# 20:	learn: 797.6410715	total: 813ms	remaining: 22.4s
# 40:	learn: 778.0508172	total: 1.29s	remaining: 17.5s
# 60:	learn: 769.8775367	total: 1.75s	remaining: 15.5s
# 80:	learn: 765.5868351	total: 2.17s	remaining: 13.9s
# 100:	learn: 761.0634544	total: 2.57s	remaining: 12.7s
# 120:	learn: 754.7760552	total: 2.86s	remaining: 11.3s
# 140:	learn: 750.9596954	total: 3.29s	remaining: 10.7s
# 160:	learn: 747.4123577	total: 3.79s	remaining: 10.3s
# 180:	learn: 744.5153973	total: 4.19s	remaining: 9.7s
# 200:	learn: 740.9301859	total: 4.6s	remaining: 9.13s
# 220:	learn: 737.5237822	total: 4.96s	remaining: 8.5s
# 240:	learn: 734.5630935	total: 5.4s	remaining: 8.04s
# 260:	learn: 731.6196451	total: 5.79s	remaining: 7.53s
# 280:	learn: 729.3706398	total: 6.29s	remaining: 7.14s
# 300:	learn: 726.6053575	total: 6.69s	remaining: 6.65s
# 320:	learn: 724.3321639	total: 7.07s	remaining: 6.14s
# 340:	learn: 722.3205074	total: 7.52s	remaining: 5.71s
# 360:	learn: 719.9421813	total: 7.94s	remaining: 5.25s
# 380:	learn: 717.8980126	total: 8.38s	remaining: 4.82s
# 400:	learn: 715.4754685	total: 8.81s	remaining: 4.37s
# 420:	learn: 713.4392200	total: 9.18s	remaining: 3.9s
# 440:	learn: 711.3867093	total: 9.62s	remaining: 3.47s
# 460:	learn: 709.7315594	total: 10s	remaining: 3.01s
# 480:	learn: 707.8645915	total: 10.4s	remaining: 2.57s
# 500:	learn: 705.9800966	total: 10.8s	remaining: 2.13s
# 520:	learn: 704.3848908	total: 11.1s	remaining: 1.68s
# 540:	learn: 702.2616458	total: 11.5s	remaining: 1.25s
# 560:	learn: 700.4067966	total: 12s	remaining: 832ms
# 580:	learn: 698.3409249	total: 12.4s	remaining: 406ms
# 599:	learn: 696.5308188	total: 12.8s	remaining: 0us

# %% [raw]
# Now, the next task is to predict the outcome for test data set.

# %%
regressor.predict(test_data)
# Out:
# array([1489.3045592 , 1290.5259012 , 1373.349014  , ..., 1679.4199694 ,
#        2566.21978321, 1628.18804144])

# %%
pred = pd.DataFrame(regressor.predict(test_data),columns= ['Time from Pickup to Arrival' ])

# %%
pred = pd.concat([samplesub['Order_No'], pred], axis =1)

# %%
pred.head()
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                  1489.304559
# 1  Order_No_12736                  1290.525901
# 2    Order_No_768                  1373.349014
# 3  Order_No_15332                  1113.323467
# 4  Order_No_21373                  1230.250877

# %%
pred  = pred.round()

# %%
pred.head()
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                       1489.0
# 1  Order_No_12736                       1291.0
# 2    Order_No_768                       1373.0
# 3  Order_No_15332                       1113.0
# 4  Order_No_21373                       1230.0

# %%
pred.to_csv("C:/Users/smesh/Desktop/surv10.csv", index = False)
